# %%
from matplotlib import pyplot as plt

# %%
years = ['Y4' , 'Y5' , 'Y6' , 'Y7' , 'Y8' , 'Y9' , 'Y10' ]

# %% [markdown]
# # NDCG@10 Y4

# %%
NEUMF_NDCG10 = [0.0030 , 0.033 , 0.015 , 0.038 , 0.015 , 0.019 , 0.025]
BPR_NCDG10 = [0.011 , 0.022 , 0.072 , 0.044 , 0.047 , 0.042 , 0.059]
plt.style.use('dark_background')
plt.plot(years, BPR_NCDG10, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(years, NEUMF_NDCG10, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0,0.12)
#plt.xlim(right='Y10')
#plt.title('NDCG@10')
plt.xlabel("years added ")
plt.ylabel("NDCG@10")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %% [markdown]
# # HR@10 Y4

# %%
#plt.style.use('dark_background')
neumf_hr10 = [0.01 , 0.09 , 0.04 , 0.08 , 0.04 , 0.05 , 0.06]
bpr_hr10 = [0.02 , 0.04 , 0.13 , 0.1 , 0.08 , 0.09 , 0.11]
plt.plot(years, bpr_hr10, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(years, neumf_hr10, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0,0.18)
#plt.xlim(right='Y10')
#plt.title('HR@10')
plt.xlabel("years added ")
plt.ylabel("HR@10")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %%
year4 = ['Y7' , 'Y8' , 'Y9' , 'Y10' ]

# %% [markdown]
# # HR@10 Y7

# %%
neumf_hr10_4 = [0.042 , 0.053 , 0.045 , 0.042]
bpr_hr10_4 = [0.056 , 0.067 , 0.077 , 0.085]
plt.style.use('dark_background')
plt.plot(year4, bpr_hr10_4, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(year4, neumf_hr10_4, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0.03,0.12)
#plt.xlim(right='Y10')
#plt.title('HR@10')
plt.xlabel("years added ")
plt.ylabel("HR@10")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %% [markdown]
# # NDCG@10 Y7

# %%
neumf_ncdg10_4 = [0.021 , 0.024 , 0.021 , 0.021]
bpr_ncdg10_4 = [0.031 , 0.040 , 0.044 , 0.048]
plt.style.use('dark_background')
plt.plot(year4, bpr_ncdg10_4, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(year4, neumf_ncdg10_4, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0.01,0.09)
#plt.xlim(right='Y10')
#plt.title('NCDG@10')
plt.xlabel("years added ")
plt.ylabel("NDCG@10")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %% [markdown]
# # HR@5 Y7

# %%
bpr_hr7 = [0.037 , 0.041 , 0.043 , 0.035]
neumf_hr7 = [0.040 , 0.043 , 0.039 , 0.039]
plt.style.use('dark_background')
plt.plot(year4, bpr_hr7, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(year4, neumf_hr7, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0.03,0.07)
#plt.xlim(right='Y10')
#plt.title('NCDG@10')
plt.xlabel("years added ")
plt.ylabel("HR@5")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %% [markdown]
# # NDCG@5 Y7

# %%
bpr_ndcg7 = [0.023 , 0.025 , 0.026 , 0.022]
neumf_hr7 = [0.027 , 0.027 , 0.025 , 0.0245]
plt.style.use('dark_background')
plt.plot(year4, bpr_ndcg7, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(year4, neumf_hr7, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0.015,0.04)
#plt.xlim(right='Y10')
#plt.title('NCDG@10')
plt.xlabel("years added ")
plt.ylabel("NDCG@5")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %%
year5=['Y5' , 'Y6' ,'Y7' , 'Y8' , 'Y9' , 'Y10'  ]

# %% [markdown]
# # HR@5 Y5

# %%
bpr_hr5 = [0.067 , 0.062 , 0.065 , 0.045 , 0.056 , 0.056]
neumf_hr5 = [0.067 , 0.05 , 0.053 , 0.06 , 0.059 , 0.053]
plt.style.use('dark_background')
plt.plot(year5, bpr_hr5, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(year5, neumf_hr5, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0.04,0.09)
#plt.xlim(right='Y10')
#plt.title('NCDG@10')
plt.xlabel("years added ")
plt.ylabel("HR@5")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>

# %% [markdown]
# # NDCG@5 Y5

# %%
bpr_ndcg5 = [0.0405 , 0.038 , 0.041 , 0.029 , 0.037 , 0.032]
neumf_ndcg5 = [0.039 , 0.026 , 0.032 , 0.038 , 0.035 , 0.032]
plt.style.use('dark_background')
plt.plot(year5, bpr_ndcg5, color='tab:green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:green', markersize=12,label='BPR')
plt.plot(year5, neumf_ndcg5, color='tab:orange', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='tab:orange', markersize=12,label='NeuMF')
plt.ylim(0.015,0.06)
#plt.xlim(right='Y10')
#plt.title('NCDG@10')
plt.xlabel("years added ")
plt.ylabel("NDCG@5")
plt.legend()
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, *, filternorm=True, filterrad=4.0, resample=None, url=None, data=None, **kwargs)>
